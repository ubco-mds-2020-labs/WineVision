# %%
import pandas as pd
wine = pd.read_csv("wine_quality.csv")

# %%
wine.head()
# Out:
#   Wine  Fixed Acidity (g/dm^3)  Volatile Acidity (g/dm^3)  \
# 0  red                     7.4                       0.70
# 1  red                     7.8                       0.88
# 2  red                     7.8                       0.76
# 3  red                    11.2                       0.28
# 4  red                     7.4                       0.70
#
#    Citric Acid (g/dm^3)  Residual Sugar (g/dm^3)  Chlorides (g/dm^3)  \
# 0                  0.00                      1.9               0.076
# 1                  0.00                      2.6               0.098
# 2                  0.04                      2.3               0.092
# 3                  0.56                      1.9               0.075
# 4                  0.00                      1.9               0.076
#
#    Free Sulfur Dioxide (mg/dm^3)  Total Sulfur Dioxide (mg/dm^3)  \
# 0                           11.0                            34.0
# 1                           25.0                            67.0
# ...

# %%
wine["Quality Factor Numeric"] = wine['Quality'].apply(lambda x: 0 if x < 6 
                                                              else (2 if x > 6 else 1))
wine.sample(10)
# Out:
#        Wine  Fixed Acidity (g/dm^3)  Volatile Acidity (g/dm^3)  \
# 3707  white                     6.5                      0.220
# 1188    red                     6.7                      0.640
# 2769  white                     7.7                      0.250
# 5945  white                     7.2                      0.340
# 1352    red                     7.6                      0.645
# 5221  white                     7.7                      0.320
# 2140  white                     7.2                      0.460
# 1320    red                     9.7                      0.660
# 4940  white                     6.9                      0.380
# 5415  white                     5.1                      0.350
#
#       Citric Acid (g/dm^3)  Residual Sugar (g/dm^3)  Chlorides (g/dm^3)  \
# 3707                  0.25                    17.10               0.050
# 1188                  0.23                     2.10               0.080
# ...

# %%
wine.to_csv('wine_quality.csv', index=False)

# %%
# Out:
#        Wine  Fixed Acidity (g/dm^3)  Volatile Acidity (g/dm^3)  \
# 0       red                     7.4                       0.70
# 1       red                     7.8                       0.88
# 2       red                     7.8                       0.76
# 3       red                    11.2                       0.28
# 4       red                     7.4                       0.70
# ...     ...                     ...                        ...
# 6489  white                     6.2                       0.21
# 6490  white                     6.6                       0.32
# 6491  white                     6.5                       0.24
# 6492  white                     5.5                       0.29
# 6493  white                     6.0                       0.21
#
#       Citric Acid (g/dm^3)  Residual Sugar (g/dm^3)  Chlorides (g/dm^3)  \
# 0                     0.00                      1.9               0.076
# ...
